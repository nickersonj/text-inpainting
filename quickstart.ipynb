# %% [markdown]
# ## Setup

# %% [markdown]
# Run this notebook on a GPU instance, such as [Google Colab](https://colab.research.google.com/).

# %% [markdown]
# Install dependencies and download clipseg:

# %%
# %%bash
#
# pip install -r requirements.txt
# git clone https://github.com/timojl/clipseg/
# wget https://owncloud.gwdg.de/index.php/s/ioHbRzFx6th32hn/download -O weights.zip
# unzip -d weights -j weights.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1 (from -r requirements.txt (line 5))
#   Cloning https://github.com/openai/CLIP.git (to revision d50d76daa670286dd6cacf3bcd80b5e4823fc8e1) to /tmp/pip-req-build-sd24m094
# Collecting diffusers==0.7.2
#   Downloading diffusers-0.7.2-py3-none-any.whl (304 kB)
# Collecting accelerate==0.14.0
#   Downloading accelerate-0.14.0-py3-none-any.whl (175 kB)
# Collecting transformers==4.24.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
# Collecting ftfy==6.1.1
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from clip==1.0->-r requirements.txt (line 5)) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from clip==1.0->-r requirements.txt (line 5)) (4.64.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from clip==1.0->-r requirements.txt (line 5)) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from clip==1.0->-r requirements.txt (line 5)) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from diffusers==0.7.2->-r requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from diffusers==0.7.2->-r requirements.txt (line 1)) (3.8.0)
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from diffusers==0.7.2->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: Pillow<10.0 in /usr/local/lib/python3.7/dist-packages (from diffusers==0.7.2->-r requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from diffusers==0.7.2->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from accelerate==0.14.0->-r requirements.txt (line 2)) (5.4.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from accelerate==0.14.0->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from accelerate==0.14.0->-r requirements.txt (line 2)) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy==6.1.1->-r requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.7.2->-r requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->accelerate==0.14.0->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->diffusers==0.7.2->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.7.2->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.7.2->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.7.2->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.7.2->-r requirements.txt (line 1)) (2022.9.24)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py): started
#   Building wheel for clip (setup.py): finished with status 'done'
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369409 sha256=82daf0c054f521bec1781b98bbaf7af6da009949bea362046cbf8340e5e9c4ee
#   Stored in directory: /root/.cache/pip/wheels/69/32/fe/e5dab0ac81ac6b332d5856c2e46221af469fdbe80ee4c3ae9c
# Successfully built clip
# Installing collected packages: tokenizers, huggingface-hub, ftfy, transformers, diffusers, clip, accelerate
# Successfully installed accelerate-0.14.0 clip-1.0 diffusers-0.7.2 ftfy-6.1.1 huggingface-hub-0.10.1 tokenizers-0.13.2 transformers-4.24.0
# Archive:  weights.zip
#  extracting: weights/rd16-uni.pth
#  extracting: weights/rd64-uni-refined.pth
#  extracting: weights/rd64-uni.pth
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-sd24m094
#   Running command git rev-parse -q --verify 'sha^d50d76daa670286dd6cacf3bcd80b5e4823fc8e1'
#   Running command git fetch -q https://github.com/openai/CLIP.git d50d76daa670286dd6cacf3bcd80b5e4823fc8e1
# Cloning into 'clipseg'...
# --2022-11-11 23:20:10--  https://owncloud.gwdg.de/index.php/s/ioHbRzFx6th32hn/download
# Resolving owncloud.gwdg.de (owncloud.gwdg.de)... 134.76.23.45
# Connecting to owncloud.gwdg.de (owncloud.gwdg.de)|134.76.23.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: �
#   9050K .......... .......... .......... .......... .......... 72.7M
#   9100K .......... .......... .......... .......... ..........  191M
#   9150K .......... .......... .......... .......... .......... 57.8M
#   9200K .......... .......... .......... .......... .......... 36.0M
#   9250K .......... .......... .......... .......... .......... 99.5M
#   9300K .......... .......... .......... .......... ..........  182M
#   9350K .......... .......... .......... .......... .......... 98.4M
#   9400K .......... .......... .......... .......... ..........  183M
#   9450K .......... .......... .......... .......... ..........  184M
#   9500K .......... .......... .......... .......... ..........  119M
#   9550K .......... .......... .......... .......... ..........  151M
#   9600K .......... .......... .......... .......... ..........  161M
#   9650K .......... .......... .......... .......... .......... 63.5M
#   9700K .......... .......... .......... .......... ..........  175M
#   9750K .......... .......... .......... .......... ..........  183M
#   9800K .......... .......... .......... .......... .......... 4.65M
#   9850K .......... .......... .......... .......... .......... 60.5M
#   9900K .........                                               146M=2.1s
#
# 2022-11-11 23:20:13 (4.60 MB/s) - ‘weights.zip’ saved [10146905]

# %% [markdown]
# Enter your HuggingFace token (create and copy from https://huggingface.co/settings/tokens):

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %% [markdown]
# You will also want to navigate to [HuggingFace stable-diffusion-inpainting](https://huggingface.co/runwayml/stable-diffusion-inpainting) to accept the model's terms.

# %% [markdown]
# Import module:

# %%
from masking_inpainting import *

# %% [markdown]
# ## Removing a squirrel

# %% [markdown]
# Since this is the first time we're running `mask_and_inpaint`, it will take longer than usual in order to download the stable diffusion inpainting model. Future calls will be faster.
#
# Note that you can run the same command multiple times to generate different versions.

# %%
input_filepath = 'images/squirrel.jpg'
mask_prompt = 'squirrel' # the object we're removing
inpaint_prompt = '' # blank since we are removing an object and not replacing it with anything specific

output_image = mask_and_inpaint(input_filepath, mask_prompt, inpaint_prompt, verbose=2)
# Out:
# Image Segmentation:
# Mask Generation:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result:

# %% [markdown]
# ## Changing the color of roses

# %%
input_filepath = 'images/roses.jpg'
mask_prompt = 'white roses'
inpaint_prompt = 'red roses'

output_image = mask_and_inpaint(input_filepath, mask_prompt, inpaint_prompt, verbose=2)
# Out:
# Image Segmentation:
# Mask Generation:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result:

# %% [markdown]
# ## Changing the food on a plate

# %%
input_filepath = 'images/food.jpg'
mask_prompt = 'food'
inpaint_prompt = 'steak and potatoes'

output_image = mask_and_inpaint(input_filepath, mask_prompt, inpaint_prompt, verbose=2)
# Out:
# Image Segmentation:
# Mask Generation:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result:

# %% [markdown]
# ## Replacing people with robots

# %%
input_filepath = 'images/lake.jpg'
mask_prompt = 'people'
inpaint_prompt = 'robot'

output_image = mask_and_inpaint(input_filepath, mask_prompt, inpaint_prompt, verbose=2)
# Out:
# Image Segmentation:
# Mask Generation:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result:
